# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("healthcare-dataset-stroke-data.csv")
df['bmi'].fillna(df['bmi'].mode()[0], inplace=True)
df['ever_married'].replace({'Yes':1, 'No':0}, inplace = True)
df['gender'].replace({'Male':1, 'Female':0, 'Other':2 }, inplace = True)
df['Residence_type'].replace({'Urban':1,'Rural':0}, inplace = True)
df['smoking_status'].replace({'formerly smoked':0, 'never smoked':1, 'smokes':2, 'Unknown':3}, inplace = True)
df['work_type'].replace({'Private':0, 'Self-employed':1, 'children':2, 'Govt_job':3, 'Never_worked':4}, inplace = True)
df.corr()['stroke'].sort_values().plot(kind='bar')
# Out:
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(df['bmi'].mode()[0], inplace=True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ever_married'].replace({'Yes':1, 'No':0}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ever_married'].replace({'Yes':1, 'No':0}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace({'Male':1, 'Female':0, 'Other':2 }, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'].replace({'Male':1, 'Female':0, 'Other':2 }, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Residence_type'].replace({'Urban':1,'Rural':0}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Residence_type'].replace({'Urban':1,'Rural':0}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['smoking_status'].replace({'formerly smoked':0, 'never smoked':1, 'smokes':2, 'Unknown':3}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['smoking_status'].replace({'formerly smoked':0, 'never smoked':1, 'smokes':2, 'Unknown':3}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['work_type'].replace({'Private':0, 'Self-employed':1, 'children':2, 'Govt_job':3, 'Never_worked':4}, inplace = True)
# C:\Users\SANGLESUMEDH\AppData\Local\Temp\ipykernel_23276\2270942369.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['work_type'].replace({'Private':0, 'Self-employed':1, 'children':2, 'Govt_job':3, 'Never_worked':4}, inplace = True)
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df['age'] = pd.cut(x = df['age'], bins = [0,12,19,30,60,100], labels = [0,1,2,3,4])
df.head()
# Out:
#       id  gender age  hypertension  heart_disease  ever_married  work_type  \
# 0   9046       1   4             0              1             1          0
# 1  51676       0   4             0              0             1          1
# 2  31112       1   4             0              1             1          0
# 3  60182       0   3             0              0             1          0
# 4   1665       0   4             1              0             1          1
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               0       1
# 1               0             202.21  28.7               1       1
# 2               0             105.92  32.5               1       1
# 3               1             171.23  34.4               2       1
# 4               0             174.12  24.0               1       1

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x = 'gender', data = df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'smoking_status', data = df)
# Out:
# <Axes: xlabel='smoking_status', ylabel='count'>

# %%
fig, ax = plt.subplots(4,4, figsize= (20,20))
sns.countplot(x = 'gender', data = df, hue = 'stroke', ax = ax[0,0])
sns.countplot(x = 'age', data = df, hue = 'hypertension', ax = ax[0,1])
sns.countplot(x = 'age', data = df, hue = 'heart_disease', ax = ax[0,2])
sns.countplot(x = 'age', data = df, hue = 'stroke', ax = ax[0,3])
#1
sns.countplot(x = 'hypertension', data = df, hue = 'stroke', ax = ax[1,0])
sns.countplot(x = 'heart_disease', data = df, hue = 'stroke', ax = ax[1,1])
sns.countplot(x = 'ever_married', data = df, hue = 'stroke', ax = ax[1,2])
sns.countplot(x = 'age', data = df, hue = 'ever_married', ax = ax[1,3])
#2
sns.countplot(x = 'work_type', data = df, hue = 'stroke', ax = ax[2,0])
sns.countplot(x = 'Residence_type', data = df, hue = 'stroke', ax = ax[2,1])
sns.countplot(x = 'smoking_status', data = df, hue = 'stroke', ax = ax[2,2])
sns.lineplot(x = 'bmi',y = 'avg_glucose_level', data = df, hue = 'stroke', ax = ax[2,3])
#3
sns.countplot(x = 'age', data = df, hue = 'smoking_status', ax = ax[3,0])
sns.countplot(x = 'work_type', data = df, hue = 'Residence_type', ax = ax[3,1])
sns.countplot(x = 'work_type', data = df, hue = 'smoking_status', ax = ax[3,2])
sns.lineplot(x = 'bmi',y = 'avg_glucose_level', data = df, hue = 'stroke', ax = ax[3,3])
# Out:
# <Axes: xlabel='bmi', ylabel='avg_glucose_level'>
